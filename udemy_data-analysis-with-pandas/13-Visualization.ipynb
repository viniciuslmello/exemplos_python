# %%
import pandas as pd
from pandas_datareader import data

# %%
# https://matplotlib.org/
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Use the `plot` Method to Render a Line Chart

# %%
# data.DataReader(name = "BB", data_source = "yahoo", start = "2007-01-01", end = "2020-12-31")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 data.DataReader(name = "BB", data_source = "yahoo", start = "2007-01-01", end = "2020-12-31")
#
# TypeError: download() got an unexpected keyword argument 'name'

# %%
import yfinance as yf
yf.pdr_override()
# y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']
y_symbols = ['BB']
from datetime import datetime
startdate = datetime(2007,1,1)
enddate = datetime(2020,12,31)
bb = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
bb
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-01-03  43.086666  44.026669  41.703335  42.849998  42.849998  34739100
# 2007-01-04  42.953335  46.316666  42.423332  46.189999  46.189999  46007700
# 2007-01-05  45.500000  47.306667  45.166668  47.099998  47.099998  41453400
# 2007-01-08  47.283333  48.410000  46.606667  47.386665  47.386665  38547300
# 2007-01-09  47.570000  47.666668  43.263332  43.666668  43.666668  74142000
# ...               ...        ...        ...        ...        ...       ...
# 2020-12-23   7.300000   7.330000   7.080000   7.090000   7.090000   9115500
# 2020-12-24   7.120000   7.240000   7.050000   7.060000   7.060000   6088300
# 2020-12-28   7.100000   7.130000   6.850000   6.880000   6.880000   9820100
# 2020-12-29   6.980000   7.000000   6.680000   6.770000   6.770000  11284200
# ...

# %%
bb.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb.plot(y = "Volume")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb.plot(y = "High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb["High"]
# Out:
# Date
# 2007-01-03    44.026669
# 2007-01-04    46.316666
# 2007-01-05    47.306667
# 2007-01-08    48.410000
# 2007-01-09    47.666668
#                 ...
# 2020-12-23     7.330000
# 2020-12-24     7.240000
# 2020-12-28     7.130000
# 2020-12-29     7.000000
# 2020-12-30     6.810000
# Name: High, Length: 3524, dtype: float64

# %%
bb["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb[["High","Close"]]
# Out:
#                  High      Close
# Date
# 2007-01-03  44.026669  42.849998
# 2007-01-04  46.316666  46.189999
# 2007-01-05  47.306667  47.099998
# 2007-01-08  48.410000  47.386665
# 2007-01-09  47.666668  43.666668
# ...               ...        ...
# 2020-12-23   7.330000   7.090000
# 2020-12-24   7.240000   7.060000
# 2020-12-28   7.130000   6.880000
# 2020-12-29   7.000000   6.770000
# 2020-12-30   6.810000   6.670000
#
# [3524 rows x 2 columns]

# %%
bb[["High","Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Modifying Plot Aesthetics with `matplotlib` Templates

# %%
import yfinance as yf
yf.pdr_override()
# y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']
y_symbols = ['BB']
from datetime import datetime
startdate = datetime(2007,1,1)
enddate = datetime(2020,12,31)
bb = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
bb
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-01-03  43.086666  44.026669  41.703335  42.849998  42.849998  34739100
# 2007-01-04  42.953335  46.316666  42.423332  46.189999  46.189999  46007700
# 2007-01-05  45.500000  47.306667  45.166668  47.099998  47.099998  41453400
# 2007-01-08  47.283333  48.410000  46.606667  47.386665  47.386665  38547300
# 2007-01-09  47.570000  47.666668  43.263332  43.666668  43.666668  74142000
# ...               ...        ...        ...        ...        ...       ...
# 2020-12-23   7.300000   7.330000   7.080000   7.090000   7.090000   9115500
# 2020-12-24   7.120000   7.240000   7.050000   7.060000   7.060000   6088300
# 2020-12-28   7.100000   7.130000   6.850000   6.880000   6.880000   9820100
# 2020-12-29   6.980000   7.000000   6.680000   6.770000   6.770000  11284200
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use('dark_background')
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use('ggplot')
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Creating Bar Graphs to Show Counts

# %%
import yfinance as yf
yf.pdr_override()
# y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']
y_symbols = ['BB']
from datetime import datetime
startdate = datetime(2007,1,1)
enddate = datetime(2020,12,31)
bb = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
bb
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-01-03  43.086666  44.026669  41.703335  42.849998  42.849998  34739100
# 2007-01-04  42.953335  46.316666  42.423332  46.189999  46.189999  46007700
# 2007-01-05  45.500000  47.306667  45.166668  47.099998  47.099998  41453400
# 2007-01-08  47.283333  48.410000  46.606667  47.386665  47.386665  38547300
# 2007-01-09  47.570000  47.666668  43.263332  43.666668  43.666668  74142000
# ...               ...        ...        ...        ...        ...       ...
# 2020-12-23   7.300000   7.330000   7.080000   7.090000   7.090000   9115500
# 2020-12-24   7.120000   7.240000   7.050000   7.060000   7.060000   6088300
# 2020-12-28   7.100000   7.130000   6.850000   6.880000   6.880000   9820100
# 2020-12-29   6.980000   7.000000   6.680000   6.770000   6.770000  11284200
# ...

# %%
def rank_performance(stock_price):
    if stock_price <= 10:
        return "Poor"
    elif stock_price <= 50:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
bb["Close"].apply(rank_performance)
# Out:
# Date
# 2007-01-03    Satisfactory
# 2007-01-04    Satisfactory
# 2007-01-05    Satisfactory
# 2007-01-08    Satisfactory
# 2007-01-09    Satisfactory
#                   ...
# 2020-12-23            Poor
# 2020-12-24            Poor
# 2020-12-28            Poor
# 2020-12-29            Poor
# 2020-12-30            Poor
# Name: Close, Length: 3524, dtype: object

# %%
bb["Close"].apply(rank_performance).value_counts()
# Out:
# Poor            1540
# Satisfactory    1125
# Stellar          859
# Name: Close, dtype: int64

# %%
bb["Close"].apply(rank_performance).value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "line")
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Creating Pie Charts to Represent Proportions

# %%
import yfinance as yf
yf.pdr_override()
# y_symbols = ['SCHAND.NS', 'TATAPOWER.NS', 'ITC.NS']
y_symbols = ['BB']
from datetime import datetime
startdate = datetime(2007,1,1)
enddate = datetime(2020,12,31)
bb = pdr.get_data_yahoo(y_symbols, start=startdate, end=enddate)
bb
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2007-01-03  43.086666  44.026669  41.703335  42.849998  42.849998  34739100
# 2007-01-04  42.953335  46.316666  42.423332  46.189999  46.189999  46007700
# 2007-01-05  45.500000  47.306667  45.166668  47.099998  47.099998  41453400
# 2007-01-08  47.283333  48.410000  46.606667  47.386665  47.386665  38547300
# 2007-01-09  47.570000  47.666668  43.263332  43.666668  43.666668  74142000
# ...               ...        ...        ...        ...        ...       ...
# 2020-12-23   7.300000   7.330000   7.080000   7.090000   7.090000   9115500
# 2020-12-24   7.120000   7.240000   7.050000   7.060000   7.060000   6088300
# 2020-12-28   7.100000   7.130000   6.850000   6.880000   6.880000   9820100
# 2020-12-29   6.980000   7.000000   6.680000   6.770000   6.770000  11284200
# ...

# %%
bb["Close"].mean()
# Out:
# 29.459240453332562

# %%
def rank_performance2(stock_price):
    if stock_price >= 29.459240453332562:
        return "Above Avarage"
    else:
        return "Below Avarage"

# %%
bb["Close"].apply(rank_performance2)
# Out:
# Date
# 2007-01-03    Above Avarage
# 2007-01-04    Above Avarage
# 2007-01-05    Above Avarage
# 2007-01-08    Above Avarage
# 2007-01-09    Above Avarage
#                   ...
# 2020-12-23    Below Avarage
# 2020-12-24    Below Avarage
# 2020-12-28    Below Avarage
# 2020-12-29    Below Avarage
# 2020-12-30    Below Avarage
# Name: Close, Length: 3524, dtype: object

# %%
bb["Close"].apply(rank_performance2).value_counts()
# Out:
# Below Avarage    2387
# Above Avarage    1137
# Name: Close, dtype: int64

# %%
plt.style.use("dark_background")

# %%
bb["Close"].apply(rank_performance2).value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_performance2).value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Close'>

# %%
bb["Close"].apply(rank_performance2).value_counts().plot(kind = "pie", legend = True)
# Out:
# <AxesSubplot:ylabel='Close'>
