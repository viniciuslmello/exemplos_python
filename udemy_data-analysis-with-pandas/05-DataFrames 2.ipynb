# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
pd.to_datetime(df["Start Date"])
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 62.6+ KB

# %%
df["Last Login Time"]
# Out:
# 0      12:42 PM
# 1       6:53 AM
# 2      11:17 AM
# 3       1:00 PM
# 4       4:47 PM
#          ...
# 995     6:09 AM
# 996     6:30 AM
# 997    12:39 PM
# 998     4:45 PM
# 999     6:24 PM
# Name: Last Login Time, Length: 1000, dtype: object

# %%
pd.to_datetime(df["Last Login Time"])
# Out:
# 0     2022-09-09 12:42:00
# 1     2022-09-09 06:53:00
# 2     2022-09-09 11:17:00
# 3     2022-09-09 13:00:00
# 4     2022-09-09 16:47:00
#               ...
# 995   2022-09-09 06:09:00
# 996   2022-09-09 06:30:00
# 997   2022-09-09 12:39:00
# 998   2022-09-09 16:45:00
# 999   2022-09-09 18:24:00
# Name: Last Login Time, Length: 1000, dtype: datetime64[ns]

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [1000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df["Senior Management"] = df["Senior Management"].astype("boolean")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    boolean
#  7   Team               957 non-null    object
# dtypes: boolean(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 56.8+ KB

# %%
df["Gender"]
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df["Gender"].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
df["Gender"] = df["Gender"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    boolean
#  7   Team               957 non-null    object
# dtypes: boolean(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 50.1+ KB

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
# df["Start Date"] = pd.to_datetime(df["Start Date"])
# df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# ### Filter a DataFrame based on a condition

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
df["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-09-09 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
df["Team"] == "Finance"
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996     True
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
df[df["Team"] == "Finance"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-09-09 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-09-09 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-09-09 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-09-09 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-09-09 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-09-09 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 <NA>  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
mask = df["Team"] == "Finance"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-09-09 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-09-09 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-09-09 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-09-09 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-09-09 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-09-09 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 <NA>  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
df["Senior Management"]
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: boolean

# %%
df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-09-09 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-09-09 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-09-09 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-09-09 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 6                 True          Product
# ..                 ...              ...
# 991               True        Marketing
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 999               True            Sales
#
# [468 rows x 8 columns]

# %%
df["Team"] != "Marketing"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Team, Length: 1000, dtype: bool

# %%
df[df["Team"] != "Marketing"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [902 rows x 8 columns]

# %%
mask = df["Team"] != "Marketing"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [902 rows x 8 columns]

# %%
df["Salary"] > 110000
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Salary, Length: 1000, dtype: bool

# %%
df[df["Salary"] > 110000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2022-09-09 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2022-09-09 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2022-09-09 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2022-09-09 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
df["Bonus %"] < 1.5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997     True
# 998    False
# 999    False
# Name: Bonus %, Length: 1000, dtype: bool

# %%
mask = df["Bonus %"] < 1.5
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
#
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2022-09-09 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2022-09-09 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2022-09-09 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2022-09-09 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2022-09-09 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2022-09-09 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2022-09-09 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2022-09-09 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2022-09-09 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# ### Exercise

# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
# import pandas as pd

# This challenge includes a the_office.csv dataset.
# It is a listing of all episodes in the popular American sitcom The Office.
# The dataset has 7 columns:
# Season, Episode, Name, Director, Writer, Airdate, Viewership
# Import the the_office.csv fille into a DataFrame. 
# Tell pandas to parse the values in the Airdate column as datetime values.
# Finally, assign the imported DataFrame to an 'office' variable.
# office = pd.read_csv("the_office.csv", parse_dates = ["Airdate"])

# CHALLENGE 1:
# Find all episodes with a Writer of "Greg Daniels"
# Assign the resulting DataFrame to a 'written_by_greg' variable.
# written_by_greg = office[office["Writer"] == "Greg Daniels"]

# CHALLENGE 2:
# Find all episodes BEFORE season 8 (not including season 8)
# Assign the resulting DataFrame to a 'good_episodes' variable
# good_episodes = office[office["Season"] < 8]

# CHALLENGE 3:
# Find all episodes that aired before 1/1/2008.
# Assign the resulting DataFrame to an 'early_episodes' variable.
# early_episodes = office[office["Airdate"] < "2008-01-01"]

# %% [markdown]
# ### Filter with more than one condition (AND)

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"
df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2022-09-09 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2022-09-09 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2022-09-09 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2022-09-09 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2022-09-09 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2022-09-09 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2022-09-09 15:05:00   41054   12.299
# 484              False  Marketing
# 496               True  Marketing
# 503               True  Marketing
# 544               True  Marketing
# 550               True  Marketing
# 556               True  Marketing
# 571              False  Marketing
# 581              False  Marketing
# 696               True  Marketing
# 722               True  Marketing
# 798               True  Marketing
# 860              False  Marketing
# 867              False  Marketing
# 899               True  Marketing
# 947               <NA>  Marketing
# 994               True  Marketing

# %% [markdown]
# ### Exercise

# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
# import pandas as pd

# This challenge includes a the_office.csv dataset.
# It is a listing of all episodes in the popular American sitcom The Office.
# The dataset has 7 columns:
# Season, Episode, Name, Director, Writer, Airdate, Viewership
# Import the the_office.csv file into a DataFrame. 
# Tell pandas to parse the values in the Airdate column as datetime values.
# Finally, assign the imported DataFrame to an 'office' variable.
# office = pd.read_csv("the_office.csv", parse_dates = ["Airdate"])

# CHALLENGE 1:
# Find all episodes with a Viewership greater than 10
# who are also directed by Jeffrey Blitz
# Assign the resulting DataFrame to a 'jeffs_episodes' variable.
# mask1 = office["Viewership"] > 10
# mask2 = office["Director"] == "Jeffrey Blitz"
# jeffs_episodes = office[mask1 & mask2]

# CHALLENGE 2:
# Find all episodes in season 5 that have an episode number
# greater than or equal to 13.
# Assign the resulting DataFrame to a "second_half_of_season_5" variable.
# mask1 = office["Season"] == 5
# mask2 = office["Episode"] >= 13
# second_half_of_season_5 = office[mask1 & mask2]

# CHALLENGE 3:
# Find all episodes that were the 6th episode of their season
# and also aired before 01/01/2010.
# Assign the resulting DataFrame to a "sixth_episodes_of_early_seasons" variable.
# mask1 = office["Airdate"] < '2010-01-01'
# mask2 = office["Episode"] == 6
# sixth_episodes_of_early_seasons = office[mask1 & mask2]

# %% [markdown]
# ### Filter with more than one condition (OR)

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
mask1 = df["Senior Management"]
mask2 = df["Start Date"] < "1990-01-01"
df[mask1 | mask2]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-09-09 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-09-09 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [599 rows x 8 columns]

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2022-09-09 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2022-09-09 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2022-09-09 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2022-09-09 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ### Excercise

# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
# import pandas as pd

# This challenge includes a the_office.csv dataset.
# It is a listing of all episodes in the popular American sitcom The Office.
# The dataset has 7 columns:
# Season, Episode, Name, Director, Writer, Airdate, Viewership
# Import the the_office.csv file into a DataFrame. 
# Tell pandas to parse the values in the Airdate column as datetime values.
# Finally, assign the imported DataFrame to an 'office' variable.
# office = pd.read_csv("the_office.csv", parse_dates = ["Airdate"])

# CHALLENGE 1:
# Find all episodes that were EITHER in Season 4
# OR directed by Harold Ramis
# Assign the resulting DataFrame to a 'season_4_or_harold' variable.
# mask1 = office["Season"] == 4
# mask2 = office["Director"] == "Harold Ramis"
# season_4_or_harold = office[mask1 | mask2]

# CHALLENGE 2:
# Find all episodes that EITHER had a Viewership less than 4
# OR aired on/after January 1st, 2013.
# Assign the resulting DataFrame to a 'low_viewership_or_later_airdate' variable.
# mask1 = office["Viewership"] < 4
# mask2 = office["Airdate"] >= "2013-01-01"
# low_viewership_or_later_airdate = office[mask1 | mask2]

# CHALLENGE 3:
# Find all episodes that EITHER the 9th episode of their season
# OR had an episode Name of "Niagara"
# Assign the resulting DataFrame to a 'ninth_or_niagara' variable.
# mask1 = office["Episode"] == 9
# mask2 = office["Name"] == "Niagara"
# ninth_or_niagara = office[mask1 | mask2]

# %% [markdown]
# ### The .isin() method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-09-09 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-09-09 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-09-09 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-09-09 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-09-09 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-09-09 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-09-09 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
mask = df["Team"].isin(["Legal", "Sales", "Product"])
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-09-09 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-09-09 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-09-09 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-09-09 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-09-09 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-09-09 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-09-09 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ### Excercise

# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
# import pandas as pd

# This challenge includes a billboard.csv dataset.
# It is a list of the top-selling albums of all time according to Billboard
# The dataset has 5 columns:
# Artist,Album,Released,Genre,Sales
# Import the billboard.csv fille into a DataFrame. 
# Assign the imported DataFrame to an 'billboard' variable.
# billboard = pd.read_csv("billboard.csv")

# CHALLENGE 1
# Find all records with an Artist of either Michael Jackson,
# Whitney Houston, or Celine Dion. Assign the resulting 
# DataFrame to a "trios" DataFrame.
# mask = billboard["Artist"].isin(["Michael Jackson", "Whitney Houston", "Celine Dion"])
# trios = billboard[mask]

# CHALLENGE 2
# Find all records with Sales of either 25, 35, or 45
# million copies. Note that the 'Sales' column's integers
# reflect album sales in millions. Assign the resulting DataFrame
# to a 'fives' DataFrame
# mask = billboard["Sales"].isin([25, 35, 45])
# fives = billboard[mask]

# CHALLENGE 3
# Find all records released in either 1979, 1989, or 1999.
# Assign the resulting DataFrame to a 'end_of_decade' DataFrame.
# mask = billboard["Released"].isin([1979, 1989, 1999])
# end_of_decade = billboard[mask]

# %% [markdown]
# ### The .isnull() and .notnull() methods

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
df["Team"].isnull()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Team, Length: 1000, dtype: bool

# %%
mask = df["Team"].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 
# 864         Ryan    Male 2012-11-16 2022-09-09 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2022-09-09 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                <NA>  NaN
# 32                <NA>  NaN
# 91               False  NaN
# 109              False  NaN
# 139               <NA>  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               <NA>  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               <NA>  NaN
# 573               True  NaN
# 580              False  NaN
# 626               <NA>  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               <NA>  NaN
# 781              False  NaN
# 794              False  NaN
# 826               <NA>  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               <NA>  NaN

# %%
df["Gender"].notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
condition = df["Gender"].notnull()
df[condition]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-09-09 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# ### The .between() method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-09-09 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-09-09 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-09-09 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-09-09 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-09-09 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-09-09 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-09-09 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
mask = df["Salary"].between(60000,70000)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-09-09 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-09-09 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2022-09-09 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2022-09-09 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2022-09-09 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2022-09-09 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2022-09-09 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2022-09-09 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2022-09-09 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2022-09-09 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
df[df["Bonus %"].between(2.0,5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 
# 923      Irene     NaN 1991-02-28 2022-09-09 22:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10 2022-09-09 16:58:00   38344    3.794
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               <NA>                 Legal
# 148               True                 Sales
# 166               <NA>                 Sales
# 172              False               Finance
# 220               <NA>             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               <NA>               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal

# %%
df[df["Last Login Time"].between("08:30AM","12:00PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-09-09 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2022-09-09 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-09-09 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2022-09-09 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2022-09-09 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2022-09-09 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2022-09-09 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2022-09-09 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2022-09-09 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2022-09-09 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# 7                 <NA>               Finance
# 10                True                   NaN
# 18               False       Client Services
# 33               False  Business Development
# ..                 ...                   ...
# 963               True                 Sales
# 977              False               Product
# 982               True       Human Resources
# 988              False       Human Resources
# 992               True               Finance
#
# [136 rows x 8 columns]

# %% [markdown]
# ### Excercise

# %%
# If you see a test failure when checking your solution,
# note that [left] refers to YOUR code while [right]
# refers to the correct code that the computer is comparing
# to your work

# Let's start by importing pandas below
# import pandas as pd

# This challenge includes a weather.csv dataset. It includes
# temperature measurements (high and low) for the month of April.
# The dataset has 3 columns:
# Day, Low Temp, High Temp
# Import the weather.csv file into a DataFrame. 
# Tell pandas to parse the values in the Day column as datetime values.
# Finally, assign the imported DataFrame to a 'weather' variable.
# weather = pd.read_csv("weather.csv", parse_dates = ["Day"])

# CHALLENGE 1
# I want to see the temperature for the days between April 15, 2022 and April 22, 2022.
# Extract those rows to a new DataFrame and assign it to a 'week_of_weather' variable
# week_of_weather = weather[weather["Day"].between("2022-04-15","2022-04-22")]

# CHALLENGE 2
# Extract the rows where the value in the Low Temp column is between 30 and 50.
# Assign the new DataFrame to a "cold_days" variable.
# cold_days = weather[weather["Low Temp"].between(30,50)]

# CHALLENGE 3
# Extract the rows where the value in the High Temp column is between 50 and 75.
# Assign the new DataFrame to a "warm_days" variable.
# warm_days = weather[weather["High Temp"].between(50,75)]

# %% [markdown]
# ### The .duplicated() method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [1000 rows x 8 columns]

# %%
df["First Name"]
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df["First Name"].duplicated()
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2022-09-09 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-09-09 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [799 rows x 8 columns]

# %%
df["First Name"].duplicated(keep = "last")
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated(keep = "last")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-09-09 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2022-09-09 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product
# ..                 ...              ...
# 890               <NA>          Finance
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
#
# [799 rows x 8 columns]

# %%
df["First Name"].duplicated(keep = False)
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
#        ...
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df["First Name"].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [991 rows x 8 columns]

# %%
~df["First Name"].duplicated(keep = False)
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
#        ...
# 902    False
# 925    False
# 946    False
# 947    False
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[~df["First Name"].duplicated(keep = False)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-09-09 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-09-09 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-09-09 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-09-09 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-09-09 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-09-09 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-09-09 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-09-09 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ### The .drop_duplicates() method

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [1000 rows x 8 columns]

# %%
len(df)
# Out:
# 1000

# %%
df.drop_duplicates()
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [1000 rows x 8 columns]

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ["First Name"], keep = "first")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-09-09 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-09-09 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-09-09 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-09-09 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-09-09 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-09-09 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-09-09 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-09-09 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# 137              False     Distribution
# 300               True      Engineering
# 372               True      Engineering
# 988              False  Human Resources
# ..                 ...              ...
# 433               True            Legal
# 177               True     Distribution
# 820               True  Human Resources
# 450              False            Legal
# 7                 <NA>          Finance
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(subset = ["First Name"], keep = "last")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 538       Adam    Male 2010-10-08 2022-09-09 21:53:00   45181    3.491
# 610       Alan    Male 2012-02-17 2022-09-09 00:26:00   41453   10.084
# 959     Albert    Male 1992-09-19 2022-09-09 02:35:00   45094    5.850
# 693      Alice  Female 1995-10-16 2022-09-09 21:19:00   92799    2.782
# ..         ...     ...        ...                 ...     ...      ...
# 512      Wanda  Female 1993-04-06 2022-09-09 03:11:00   78883   19.695
# 637      Wayne    Male 2009-09-02 2022-09-09 01:37:00  126956   18.396
# 127    William    Male 2002-09-29 2022-09-09 16:09:00   66521    5.830
# 652     Willie    Male 2009-12-05 2022-09-09 05:39:00  141932    1.017
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management                  Team
# 937              False       Client Services
# 538              False       Human Resources
# 610              False               Product
# 959               True  Business Development
# 693              False                 Sales
# ..                 ...                   ...
# 512              False                   NaN
# 637              False       Human Resources
# 127              False       Human Resources
# 652               True           Engineering
# 951               <NA>                   NaN
#
# [201 rows x 8 columns]

# %%
df.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-09-09 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-09-09 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-09-09 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-09-09 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-09-09 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-09-09 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-09-09 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-09-09 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-09-09 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %%
df.drop_duplicates(subset = ["Team"], keep = False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
df.drop_duplicates(subset = ["First Name", "Team"])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-09-09 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-09-09 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2022-09-09 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2022-09-09 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2022-09-09 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2022-09-09 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2022-09-09 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# 440               True       Client Services
# 137              False          Distribution
# 141               True               Product
# 302               True       Human Resources
# ..                 ...                   ...
# 149               <NA>          Distribution
# 157               <NA>               Product
# 269               <NA>       Human Resources
# 329               <NA>           Engineering
# 481               <NA>  Business Development
#
# [769 rows x 8 columns]

# %% [markdown]
# ### The .unique() and .nunique() methods

# %%
df = pd.read_csv("employees.csv", parse_dates=["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("boolean")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-09-09 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-09-09 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-09-09 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-09-09 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-09-09 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               <NA>     Distribution
# 925               <NA>            Sales
# 946               <NA>     Distribution
# 947               <NA>        Marketing
# 951               <NA>              NaN
#
# [1000 rows x 8 columns]

# %%
df["Gender"].unique()
# Out:
# ['Male', NaN, 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
df["Team"].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique()
# Out:
# 10

# %%
df["Team"].nunique(dropna=False)
# Out:
# 11

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %% [markdown]
# ---
# Teste de extração de horas para Edílio e Maia

# %%
df["hora_apenas"] = df["Last Login Time"].dt.strftime("%r")

# %%
df["hora_apenas_2"] = df["Last Login Time"].dt.strftime("%H:%M:%S")

# %%
df["hora_apenas_3"] = df["Last Login Time"].dt.strftime("%H:%M:%f")

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-09-09 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-09-09 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-09-09 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-09-09 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-09-09 01:45:00   95327   15.120
#
#      Senior Management             Team  hora_apenas hora_apenas_2  \
# 101               True        Marketing  10:20:00 AM      10:20:00
# 327               True        Marketing  06:48:00 PM      18:48:00
# 440               True  Client Services  02:53:00 PM      14:53:00
# 937              False  Client Services  07:39:00 PM      19:39:00
# 137              False     Distribution  01:45:00 AM      01:45:00
#
#     hora_apenas_3
# 101  10:20:000000
# 327  18:48:000000
# 440  14:53:000000
# 937  19:39:000000
# 137  01:45:000000

# %% [markdown]
# ---
